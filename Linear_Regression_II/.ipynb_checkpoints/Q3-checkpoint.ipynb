# %%
import random
import numpy as np

# %%
def sgd(X,Y,alpha,theta):
    
    ch = random.randint(0,len(X)-1)
    x = X[ch]
    y = Y[ch] 
    theta = theta - alpha*gradient(x,y,theta)
    return theta

# %%
def gradient(x,y,theta): 
    
    grad = np.zeros(len(theta))
    err = error(x,y,theta)
    for j in range(len(theta)):
        grad[j] = 2*x[j]*err
    return grad

# %%
def error(x,y,theta):
    err = np.dot(x,theta)-y
    return err

# %%
X = np.array([[1,1],[1,3],[1,6]])
Y = np.array([6,10,16])
theta_list = []
theta = np.zeros(len(X[0]))
alpha = 0.01
for i in range(1000):
    theta = sgd(X,Y,alpha,theta)
    theta_list.append(theta)

# %%
theta_list
# Out:
# [array([0.2, 0.6]),
#  array([0.304, 0.704]),
#  array([0.40384, 0.80384]),
#  array([0.4996864, 0.8996864]),
#  array([0.7017303 , 2.11194982]),
#  array([0.75426172, 2.42713831]),
#  array([0.81063372, 2.48351031]),
#  array([0.81639981, 2.51810684]),
#  array([0.86970967, 2.57141671]),
#  array([0.89803048, 2.65637912]),
#  array([0.88130437, 2.5560225 ]),
#  array([0.91031694, 2.64306018]),
#  array([0.93352699, 2.71269034]),
#  array([0.95209503, 2.76839446]),
#  array([0.96694946, 2.81295775]),
#  array([0.93005554, 2.59159424]),
#  array([0.92046312, 2.53403972]),
#  array([0.97137306, 2.58494966]),
#  array([0.99684862, 2.66137634]),
#  array([1.01722907, 2.72251768]),
#  array([0.99018237, 2.56023746]),
#  array([0.98315022, 2.51804461]),
#  array([1.01240454, 2.60580756]),
#  array([1.0600403 , 2.65344332]),
#  array([1.10577063, 2.69917365]),
#  array([1.07975438, 2.54307615]),
#  array([1.07299015, 2.5024908 ]),
#  array([1.07123145, 2.4919386 ]),
#  array([1.07077419, 2.48919503]),
#  array([1.11957481, 2.53799565]),
#  array([1.14490357, 2.61398194]),
#  array([1.12832767, 2.51452652]),
#  array([1.15488952, 2.59421208]),
#  array([1.17613901, 2.65796054]),
#  array([1.15366096, 2.52309227]),
#  array([1.17920221, 2.599716  ]),
#  array([1.1996352 , 2.66101499]),
#  array([1.2424222 , 2.70380199]),
#  array([1.21311752, 2.52797389]),
#  array([1.2054983 , 2.48225859]),
#  array([1.23245282, 2.56312214]),
#  array([1.22022911, 2.48977986]),
#  array([1.26602893, 2.53557968]),
#  array([1.25643879, 2.47803884]),
#  array([1.28262768, 2.55660552]),
#  array([1.32584302, 2.59982086]),
#  array([1.36732974, 2.64130758]),
#  array([1.34302623, 2.49548655]),
#  array([1.33670732, 2.45757309]),
#  array([1.38082171, 2.50168748]),
#  array([1.37300278, 2.45477389]),
#  array([1.41644725, 2.49821836]),
#  array([1.4083321 , 2.44952747]),
#  array([1.45117491, 2.49237028]),
#  array([1.47260919, 2.55667313]),
#  array([1.48975662, 2.60811542]),
#  array([1.52779918, 2.64615798]),
#  array([1.49970424, 2.47758833]),
#  array([1.49239956, 2.43376022]),
#  array([1.51652595, 2.50613941]),
#  array([1.53582707, 2.56404276]),
#  array([1.55126796, 2.61036544]),
#  array([1.58803529, 2.64713277]),
#  array([1.55861866, 2.47063294]),
#  array([1.59803362, 2.51004791]),
#  array([1.61547008, 2.56235727]),
#  array([1.65191353, 2.59880072]),
#  array([1.68689924, 2.63378644]),
#  array([1.69513407, 2.65849092]),
#  array([1.72806157, 2.69141842]),
#  array([1.75967197, 2.72302882]),
#  array([1.7610968 , 2.72730332]),
#  array([1.76223667, 2.73072291]),
#  array([1.79237748, 2.76086372]),
#  array([1.79087811, 2.7563656 ]),
#  array([1.81993323, 2.78542073]),
#  array([1.84782615, 2.81331365]),
#  array([1.84207081, 2.79604762]),
#  array([1.78970368, 2.48184484]),
#  array([1.82427271, 2.51641387]),
#  array([1.83680242, 2.55400301]),
#  array([1.86898631, 2.5861869 ]),
#  array([1.89988285, 2.61708344]),
#  array([1.90486019, 2.63201545]),
#  array([1.90884206, 2.64396105]),
#  array([1.91202755, 2.65351754]),
#  array([1.91457595, 2.66116273]),
#  array([1.91661467, 2.66727888]),
#  array([1.87820891, 2.43684433]),
#  array([1.89443407, 2.48551981]),
#  array([1.9074142, 2.5244602]),
#  array([1.93877671, 2.55582272]),
#  array([1.96888472, 2.58593073]),
#  array([1.93919534, 2.40779444]),
#  array([1.9314761, 2.361479 ]),
#  array([1.965617 , 2.3956199]),
#  array([1.95883027, 2.35489953]),
#  array([1.95706572, 2.34431224]),
#  array([1.95660694, 2.34155954]),
#  array([1.99064361, 2.37559621]),
#  array([1.98575919, 2.34628971]),
#  array([1.98448924, 2.33867001]),
#  array([1.98415906, 2.33668889]),
#  array([2.00427454, 2.39703535]),
#  array([1.99654481, 2.35065695]),
#  array([2.0155745 , 2.40774601]),
#  array([2.03079825, 2.45341726]),
#  array([2.01577221, 2.36326104]),
#  array([2.01186544, 2.33982043]),
#  array([2.03123891, 2.39794082]),
#  array([2.04673768, 2.44443714]),
#  array([2.0591367, 2.4816342]),
#  array([2.04015786, 2.36776117]),
#  array([2.07199948, 2.39960279]),
#  array([2.08658332, 2.44335432]),
#  array([2.09825039, 2.47835554]),
#  array([2.10758405, 2.50635652]),
#  array([2.13530524, 2.53407771]),
#  array([2.14055448, 2.54982541]),
#  array([2.16674688, 2.57601781]),
#  array([2.19189158, 2.60116252]),
#  array([2.191984  , 2.60143977]),
#  array([2.19205794, 2.60166157]),
#  array([2.19211708, 2.60183901]),
#  array([2.21623796, 2.62595989]),
#  array([2.17679801, 2.38932021]),
#  array([2.18990284, 2.42863469]),
#  array([2.2003867 , 2.46008628]),
#  array([2.20877379, 2.48524755]),
#  array([2.18636861, 2.35081646]),
#  array([2.21562491, 2.38007276]),
#  array([2.24371096, 2.4081588 ]),
#  array([2.25434721, 2.44006756]),
#  array([2.23645216, 2.33269725]),
#  array([2.25176128, 2.37862462]),
#  array([2.26400858, 2.41536651]),
#  array([2.27380641, 2.44476002]),
#  array([2.28164468, 2.46827483]),
#  array([2.2879153 , 2.48708668]),
#  array([2.26370659, 2.34183444]),
#  array([2.25741233, 2.30406885]),
#  array([2.28618271, 2.33283923]),
#  array([2.3004887, 2.3757572]),
#  array([2.31193349, 2.41009159]),
#  array([2.32108933, 2.43755909]),
#  array([2.30216045, 2.32398583]),
#  array([2.29723894, 2.29445678]),
#  array([2.32540503, 2.32262286]),
#  array([2.35244447, 2.34966231]),
#  array([2.3434361 , 2.29561211]),
#  array([2.37065514, 2.32283115]),
#  array([2.38387217, 2.36248223]),
#  array([2.37269686, 2.29543036]),
#  array([2.3875171 , 2.33989109]),
#  array([2.41296893, 2.36534292]),
#  array([2.4374027 , 2.38977669]),
#  array([2.46085911, 2.4132331 ]),
#  array([2.46684794, 2.43119959]),
#  array([2.48888699, 2.45323864]),
#  array([2.46472061, 2.30824038]),
#  array([2.48926139, 2.33278116]),
#  array([2.47954243, 2.27446736]),
#  array([2.50446223, 2.29938716]),
#  array([2.52838524, 2.32331017]),
#  array([2.53841893, 2.35341123]),
#  array([2.5252412 , 2.27434487]),
#  array([2.52181499, 2.25378762]),
#  array([2.53615143, 2.29679695]),
#  array([2.55949247, 2.32013798]),
#  array([2.54988606, 2.26249954]),
#  array([2.54738839, 2.24751354]),
#  array([2.57149036, 2.2716155 ]),
#  array([2.56746669, 2.2474735 ]),
#  array([2.58126894, 2.28888027]),
#  array([2.60386596, 2.31147728]),
#  array([2.59441137, 2.25474972]),
#  array([2.59195317, 2.24000056]),
#  array([2.59131404, 2.23616578]),
#  array([2.61476445, 2.25961618]),
#  array([2.63727683, 2.28212857]),
#  array([2.65888873, 2.30374046]),
#  array([2.67963614, 2.32448788]),
#  array([2.66710487, 2.24930027]),
#  array([2.66384674, 2.22975149]),
#  array([2.66299963, 2.22466881]),
#  array([2.66277938, 2.22334731]),
#  array([2.67612295, 2.26337803]),
#  array([2.68679781, 2.29540261]),
#  array([2.67761354, 2.24029699]),
#  array([2.69925533, 2.26193878]),
#  array([2.72003145, 2.2827149 ]),
#  array([2.71170503, 2.2327564 ]),
#  array([2.72350555, 2.26815794]),
#  array([2.74367228, 2.28832467]),
#  array([2.73419987, 2.23149024]),
#  array([2.75488607, 2.25217643]),
#  array([2.76465776, 2.28149151]),
#  array([2.75558563, 2.22705869]),
#  array([2.76685039, 2.26085299]),
#  array([2.77586221, 2.28788843]),
#  array([2.79458719, 2.30661342]),
#  array([2.80029864, 2.32374777]),
#  array([2.81781772, 2.34126684]),
#  array([2.82098535, 2.35076975]),
#  array([2.83755025, 2.36733464]),
#  array([2.85345255, 2.38323695]),
#  array([2.83039507, 2.24489204]),
#  array([2.84888932, 2.2633863 ]),
#  array([2.84030518, 2.21188144]),
#  array([2.85078619, 2.24332447]),
#  array([2.84457153, 2.20603651]),
#  array([2.86355937, 2.22502435]),
#  array([2.85928526, 2.19937969]),
#  array([2.87013677, 2.23193423]),
#  array([2.88809535, 2.24989281]),
#  array([2.89533988, 2.27162638]),
#  array([2.88483791, 2.2086146 ]),
#  array([2.8821074 , 2.19223154]),
#  array([2.89293136, 2.22470342]),
#  array([2.90159053, 2.25068092]),
#  array([2.89347701, 2.20199979]),
#  array([2.91156747, 2.22009026]),
#  array([2.92893432, 2.2374571 ]),
#  array([2.93610821, 2.25897877]),
#  array([2.95220647, 2.27507703]),
#  array([2.95665772, 2.28843077]),
#  array([2.94291287, 2.20596169]),
#  array([2.95169691, 2.23231381]),
#  array([2.95872414, 2.25339551]),
#  array([2.97448175, 2.26915312]),
#  array([2.97884293, 2.28223665]),
#  array([2.96539767, 2.20156511]),
#  array([2.9619019 , 2.18059051]),
#  array([2.97182844, 2.2103701 ]),
#  array([2.98818447, 2.22672613]),
#  array([2.98121364, 2.18490118]),
#  array([2.99789134, 2.20157889]),
#  array([2.99374405, 2.17669513]),
#  array([3.00326746, 2.20526536]),
#  array([3.01909681, 2.2210947 ]),
#  array([3.02544919, 2.24015185]),
#  array([3.03053109, 2.25539757]),
#  array([3.04481252, 2.26967899]),
#  array([3.05852269, 2.28338916]),
#  array([3.06034889, 2.28886775]),
#  array([3.07336455, 2.30188342]),
#  array([3.07378426, 2.30314253]),
#  array([3.05593147, 2.1960258 ]),
#  array([3.06305129, 2.21738527]),
#  array([3.07744256, 2.23177653]),
#  array([3.06808052, 2.17560432]),
#  array([3.07618265, 2.19991071]),
#  array([3.08266436, 2.21935583]),
#  array([3.08784972, 2.23491192]),
#  array([3.0779033 , 2.17523337]),
#  array([3.09284056, 2.19017064]),
#  array([3.09957351, 2.21036949]),
#  array([3.10495987, 2.22652857]),
#  array([3.09567725, 2.17083281]),
#  array([3.11034705, 2.18550261]),
#  array([3.12443005, 2.19958562]),
#  array([3.11799118, 2.16095237]),
#  array([3.11631707, 2.15090772]),
#  array([3.13097258, 2.16556323]),
#  array([3.14504186, 2.17963251]),
#  array([3.14058512, 2.15289208]),
#  array([3.15471558, 2.16702254]),
#  array([3.15157856, 2.14820044]),
#  array([3.15965496, 2.17242965]),
#  array([3.15577031, 2.14912171]),
#  array([3.1637076 , 2.17293358]),
#  array([3.17005743, 2.19198308]),
#  array([3.1751373 , 2.20722268]),
#  array([3.1874901 , 2.21957548]),
#  array([3.19934879, 2.23143417]),
#  array([3.20147576, 2.23781509]),
#  array([3.20317734, 2.24291983]),
#  array([3.2045386 , 2.24700362]),
#  array([3.20562761, 2.25027065]),
#  array([3.20649882, 2.25288428]),
#  array([3.20719579, 2.25497518]),
#  array([3.19245485, 2.16652956]),
#  array([3.18862221, 2.14353369]),
#  array([3.20197909, 2.15689057]),
#  array([3.19911264, 2.13969187]),
#  array([3.19836736, 2.13522021]),
#  array([3.19817359, 2.13405757]),
#  array([3.20616666, 2.1580368 ]),
#  array([3.21256112, 2.17722017]),
#  array([3.21767669, 2.19256687]),
#  array([3.22176914, 2.20484424]),
#  array([3.22504311, 2.21466612]),
#  array([3.22766228, 2.22252364]),
#  array([3.23865856, 2.23351992]),
#  array([3.23987419, 2.23716682]),
#  array([3.25033337, 2.247626  ]),
#  array([3.23561159, 2.15929527]),
#  array([3.23178392, 2.13632929]),
#  array([3.23078873, 2.13035813]),
#  array([3.24356579, 2.14313519]),
#  array([3.25010636, 2.16275691]),
#  array([3.2618491 , 2.17449964]),
#  array([3.27312212, 2.18577267]),
#  array([3.27651332, 2.19594626]),
#  array([3.27922628, 2.20408514]),
#  array([3.26915154, 2.14363668]),
#  array([3.2665321 , 2.12792009]),
#  array([3.26585105, 2.12383377]),
#  array([3.26567398, 2.12277133]),
#  array([3.27299422, 2.14473205]),
#  array([3.28463969, 2.15637753]),
#  array([3.29581935, 2.16755718]),
#  array([3.29984953, 2.17964773]),
#  array([3.29229481, 2.13431942]),
#  array([3.29838975, 2.15260424]),
#  array([3.29410945, 2.12692242]),
#  array([3.30568881, 2.13850178]),
#  array([3.30295482, 2.12209784]),
#  array([3.30224398, 2.11783282]),
#  array([3.30205917, 2.11672391]),
#  array([3.30901455, 2.13759006]),
#  array([3.32008246, 2.14865796]),
#  array([3.31584185, 2.12321434]),
#  array([3.31473929, 2.11659899]),
#  array([3.31445263, 2.114879  ]),
#  array([3.32127084, 2.13533362]),
#  array([3.33213875, 2.14620154]),
#  array([3.34257194, 2.15663473]),
#  array([3.34632242, 2.16788616]),
#  array([3.3493228 , 2.17688731]),
#  array([3.34110987, 2.12760971]),
#  array([3.33897451, 2.11479753]),
#  array([3.34989906, 2.12572209]),
#  array([3.36038664, 2.13620967]),
#  array([3.37045472, 2.14627774]),
#  array([3.38012007, 2.1559431 ]),
#  array([3.38316108, 2.16506613]),
#  array([3.37568992, 2.12023919]),
#  array([3.38096177, 2.13605474]),
#  array([3.38517925, 2.14870718]),
#  array([3.38855324, 2.15882913]),
#  array([3.39760559, 2.16788148]),
#  array([3.40629585, 2.17657174]),
#  array([3.4146385 , 2.18491439]),
#  array([3.42264744, 2.19292333]),
#  array([3.41104369, 2.12330084]),
#  array([3.4203568 , 2.13261395]),
#  array([3.42929738, 2.14155454]),
#  array([3.43788034, 2.1501375 ]),
#  array([3.43110624, 2.10949286]),
#  array([3.42934497, 2.09892525]),
#  array([3.43877957, 2.10835985]),
#  array([3.43700079, 2.09768721]),
#  array([3.44630703, 2.10699345]),
#  array([3.45096129, 2.12095621]),
#  array([3.45952294, 2.12951786]),
#  array([3.46256141, 2.13863327]),
#  array([3.45667419, 2.10330995]),
#  array([3.46134211, 2.1173137 ]),
#  array([3.46976899, 2.12574059]),
#  array([3.46528474, 2.09883509]),
#  array([3.47004894, 2.11312769]),
#  array([3.47838541, 2.12146415]),
#  array([3.474242  , 2.09660371]),
#  array([3.47896094, 2.11076053]),
#  array([3.47609045, 2.09353763]),
#  array([3.47534413, 2.08905968]),
#  array([3.48405605, 2.09777161]),
#  array([3.4924195 , 2.10613505]),
#  array([3.4898349 , 2.09062748]),
#  array([3.48916291, 2.0865955 ]),
#  array([3.48898819, 2.08554719]),
#  array([3.48894276, 2.08527463]),
#  array([3.49404743, 2.10058863]),
#  array([3.49209585, 2.08887913]),
#  array([3.49692118, 2.10335513]),
#  array([3.50078145, 2.11493594]),
#  array([3.5084671 , 2.12262159]),
#  array([3.51094046, 2.13004168]),
#  array([3.51812082, 2.13722203]),
#  array([3.51129176, 2.09624767]),
#  array([3.51529107, 2.10824558]),
#  array([3.51199577, 2.08847384]),
#  array([3.51644743, 2.1018288 ]),
#  array([3.51389902, 2.08653837]),
#  array([3.51842874, 2.10012752]),
#  array([3.52605762, 2.1077564 ]),
#  array([3.5226057 , 2.08704488]),
#  array([3.5217082 , 2.08165988]),
#  array([3.52147485, 2.08025978]),
#  array([3.52944015, 2.08822509]),
#  array([3.52826434, 2.08117021]),
#  array([3.53607565, 2.08898152]),
#  array([3.54001525, 2.1008003 ]),
#  array([3.54316692, 2.11025533]),
#  array([3.55009848, 2.11718689]),
#  array([3.55675277, 2.12384118]),
#  array([3.56314089, 2.1302293 ]),
#  array([3.55625056, 2.0888873 ]),
#  array([3.55445907, 2.07813838]),
#  array([3.55399328, 2.07534366]),
#  array([3.56140654, 2.08275692]),
#  array([3.56852327, 2.08987365]),
#  array([3.57176039, 2.099585  ]),
#  array([3.57435008, 2.10735407]),
#  array([3.580716  , 2.11371999]),
#  array([3.58227848, 2.11840743]),
#  array([3.57642402, 2.08328066]),
#  array([3.5798987, 2.0937047]),
#  array([3.57705616, 2.07664947]),
#  array([3.58091607, 2.0882292 ]),
#  array([3.58753316, 2.09484629]),
#  array([3.59009172, 2.10252197]),
#  array([3.58598725, 2.07789514]),
#  array([3.5895938 , 2.08871478]),
#  array([3.59247904, 2.09737049]),
#  array([3.59868204, 2.1035735 ]),
#  array([3.59427958, 2.07715874]),
#  array([3.60085082, 2.08372997]),
#  array([3.60381   , 2.09260753]),
#  array([3.60988165, 2.09867918]),
#  array([3.61176327, 2.10432402]),
#  array([3.60700912, 2.07579913]),
#  array([3.60577304, 2.06838266]),
#  array([3.61228993, 2.07489955]),
#  array([3.61854614, 2.08115576]),
#  array([3.62130587, 2.08943495]),
#  array([3.62709105, 2.09522014]),
#  array([3.62883602, 2.10045505]),
#  array([3.630232  , 2.10464298]),
#  array([3.63134878, 2.10799332]),
#  array([3.63224221, 2.1106736 ]),
#  array([3.62631653, 2.07511954]),
#  array([3.62928303, 2.08401903]),
#  array([3.63165622, 2.09113863]),
#  array([3.63720033, 2.09668273]),
#  array([3.64252267, 2.10200507]),
#  array([3.6374316, 2.0714587]),
#  array([3.63610793, 2.06351664]),
#  array([3.63576377, 2.06145171]),
#  array([3.6393614 , 2.07224457]),
#  array([3.64223949, 2.08087887]),
#  array([3.63968924, 2.06557734]),
#  array([3.63902617, 2.06159895]),
#  array([3.64254971, 2.07216957]),
#  array([3.64536854, 2.08062606]),
#  array([3.65084865, 2.08610617]),
#  array([3.65610956, 2.09136707]),
#  array([3.65750534, 2.09555443]),
#  array([3.65862197, 2.09890431]),
#  array([3.65951527, 2.10158422]),
#  array([3.66429328, 2.10636223]),
#  array([3.66888017, 2.11094912]),
#  array([3.66218867, 2.07080013]),
#  array([3.66044888, 2.0603614 ]),
#  array([3.65999654, 2.05764732]),
#  array([3.66564366, 2.06329445]),
#  array([3.66473545, 2.05784521]),
#  array([3.66797003, 2.06754894]),
#  array([3.67325965, 2.07283856]),
#  array([3.67542415, 2.07933204]),
#  array([3.68032902, 2.08423692]),
#  array([3.68166823, 2.08825453]),
#  array([3.68273959, 2.09146862]),
#  array([3.67810856, 2.06368246]),
#  array([3.68072544, 2.07153311]),
#  array([3.68281895, 2.07781362]),
#  array([3.6876063 , 2.08260097]),
#  array([3.69220215, 2.08719682]),
#  array([3.6931263 , 2.08996927]),
#  array([3.68846746, 2.06201624]),
#  array([3.68725616, 2.05474845]),
#  array([3.69022613, 2.06365836]),
#  array([3.69514844, 2.06858067]),
#  array([3.69713064, 2.07452724]),
#  array([3.69424475, 2.05721195]),
#  array([3.69349442, 2.05270998]),
#  array([3.69329934, 2.05153946]),
#  array([3.69634098, 2.0606644 ]),
#  array([3.70120088, 2.06552429]),
#  array([3.7032454 , 2.07165787]),
#  array([3.70774734, 2.0761598 ]),
#  array([3.71206919, 2.08048166]),
#  array([3.71621818, 2.08463064]),
#  array([3.71173814, 2.0577504 ]),
#  array([3.71403835, 2.06465104]),
#  array([3.71846456, 2.06907725]),
#  array([3.72271373, 2.07332641]),
#  array([3.72385987, 2.07676484]),
#  array([3.72017089, 2.05463097]),
#  array([3.71921175, 2.04887617]),
#  array([3.72385   , 2.05351441]),
#  array([3.72295127, 2.04812203]),
#  array([3.7227176 , 2.04672002]),
#  array([3.72546004, 2.05494736]),
#  array([3.7298519 , 2.05933921]),
#  array([3.73169451, 2.06486704]),
#  array([3.73576327, 2.06893581]),
#  array([3.73691186, 2.07238157]),
#  array([3.73783073, 2.07513817]),
#  array([3.73405753, 2.052499  ]),
#  array([3.73622644, 2.05900573]),
#  array([3.7403218 , 2.06310109]),
#  array([3.7417293 , 2.06732358]),
#  array([3.7428553 , 2.07070158]),
#  array([3.7437561 , 2.07340398]),
#  array([3.7400725 , 2.05130238]),
#  array([3.744245  , 2.05547488]),
#  array([3.7482506 , 2.05948049]),
#  array([3.74971676, 2.06387896]),
#  array([3.74705695, 2.0479201 ]),
#  array([3.75115741, 2.05202056]),
#  array([3.75509385, 2.055957  ]),
#  array([3.75663455, 2.06057911]),
#  array([3.75423237, 2.046166  ]),
#  array([3.7536078, 2.0424186]),
#  array([3.75344541, 2.04144427]),
#  array([3.75340319, 2.04119095]),
#  array([3.75339222, 2.04112508]),
#  array([3.75750187, 2.04523474]),
#  array([3.75692366, 2.0417655 ]),
#  array([3.75927926, 2.04883229]),
#  array([3.76116374, 2.05448572]),
#  array([3.75940218, 2.04391635]),
#  array([3.75894417, 2.04116832]),
#  array([3.76129519, 2.04822137]),
#  array([3.76028272, 2.04214656]),
#  array([3.76254827, 2.04894322]),
#  array([3.76631844, 2.05271339]),
#  array([3.76782927, 2.05724587]),
#  array([3.76903793, 2.06087186]),
#  array([3.77243974, 2.06427366]),
#  array([3.7692781 , 2.04530386]),
#  array([3.77117431, 2.05099248]),
#  array([3.76963173, 2.04173698]),
#  array([3.77173487, 2.04804642]),
#  array([3.77533925, 2.05165079]),
#  array([3.77673341, 2.05583329]),
#  array([3.77449875, 2.04242531]),
#  array([3.77646326, 2.04831883]),
#  array([3.77803486, 2.05303365]),
#  array([3.77611013, 2.04148524]),
#  array([3.7756097 , 2.03848265]),
#  array([3.77932785, 2.0422008 ]),
#  array([3.78289728, 2.04577023]),
#  array([3.78632393, 2.04919688]),
#  array([3.78764563, 2.05316201]),
#  array([3.788703  , 2.05633411]),
#  array([3.79180226, 2.05943337]),
#  array([3.78883421, 2.04162507]),
#  array([3.79222502, 2.04501589]),
#  array([3.79097862, 2.03753744]),
#  array([3.79065455, 2.03559305]),
#  array([3.7905703 , 2.03508751]),
#  array([3.79265364, 2.04133754]),
#  array([3.79432031, 2.04633756]),
#  array([3.79565365, 2.05033758]),
#  array([3.79370007, 2.03861608]),
#  array([3.79319214, 2.0355685 ]),
#  array([3.79519419, 2.04157464]),
#  array([3.79430135, 2.0362176 ]),
#  array([3.79406921, 2.03482477]),
#  array([3.79400885, 2.03446263]),
#  array([3.79606092, 2.04061882]),
#  array([3.79526544, 2.03584596]),
#  array([3.79505862, 2.03460502]),
#  array([3.79500484, 2.03428237]),
#  array([3.7970478 , 2.04041125]),
#  array([3.79868217, 2.04531436]),
#  array([3.7972708 , 2.03684616]),
#  array([3.79690385, 2.03464443]),
#  array([3.79888711, 2.0405942 ]),
#  array([3.80209748, 2.04380457]),
#  array([3.80342726, 2.0477939 ]),
#  array([3.80640283, 2.05076948]),
#  array([3.80925939, 2.05362603]),
#  array([3.80663908, 2.03790416]),
#  array([3.80823204, 2.04268307]),
#  array([3.80950642, 2.04650619]),
#  array([3.81052592, 2.04956469]),
#  array([3.80836764, 2.036615  ]),
#  array([3.81000338, 2.04152225]),
#  array([3.81131198, 2.04544804]),
#  array([3.80963198, 2.03536801]),
#  array([3.81273198, 2.03846801]),
#  array([3.81186118, 2.03324321]),
#  array([3.81362936, 2.03854776]),
#  array([3.81273104, 2.03315785]),
#  array([3.81581326, 2.03624007]),
#  array([3.81514819, 2.03224963]),
#  array([3.81497527, 2.03121211]),
#  array([3.81680304, 2.03669542]),
#  array([3.81973307, 2.03962545]),
#  array([3.81858336, 2.03272716]),
#  array([3.82024806, 2.03772127]),
#  array([3.82157982, 2.04171656]),
#  array([3.82264523, 2.04491279]),
#  array([3.82529407, 2.04756163]),
#  array([3.82308079, 2.03428197]),
#  array([3.82456226, 2.03872637]),
#  array([3.82574743, 2.04228188]),
#  array([3.82838685, 2.0449213 ]),
#  array([3.82642855, 2.03317154]),
#  array([3.8259194 , 2.03011661]),
#  array([3.82759401, 2.03514045]),
#  array([3.83033933, 2.03788576]),
#  array([3.82918625, 2.03096729]),
#  array([3.82888645, 2.02916849]),
#  array([3.83172535, 2.03200739]),
#  array([3.83445069, 2.03473274]),
#  array([3.83567771, 2.0384138 ]),
#  array([3.83665933, 2.04135866]),
#  array([3.83744463, 2.04371454]),
#  array([3.83982144, 2.04609136]),
#  array([3.84025953, 2.04740562]),
#  array([3.84250623, 2.04965232]),
#  array([3.84466306, 2.05180915]),
#  array([3.8415527, 2.033147 ]),
#  array([3.84405871, 2.035653  ]),
#  array([3.84503835, 2.03859194]),
#  array([3.84582207, 2.04094309]),
#  array([3.84399246, 2.02996542]),
#  array([3.8465133 , 2.03248626]),
#  array([3.84893331, 2.03490627]),
#  array([3.84986027, 2.03768714]),
#  array([3.85210932, 2.03993619]),
#  array([3.85027479, 2.02892902]),
#  array([3.84979781, 2.02606715]),
#  array([3.8496738 , 2.02532306]),
#  array([3.84964155, 2.0251296 ]),
#  array([3.84963317, 2.0250793 ]),
#  array([3.84963099, 2.02506622]),
#  array([3.84963042, 2.02506282]),
#  array([3.85113404, 2.02957369]),
#  array([3.85056252, 2.02614455]),
#  array([3.85302838, 2.02861041]),
#  array([3.85253456, 2.02564751]),
#  array([3.85240617, 2.02487715]),
#  array([3.85386542, 2.0292549 ]),
#  array([3.85327752, 2.02572752]),
#  array([3.85466832, 2.02989992]),
#  array([3.85578096, 2.03323783]),
#  array([3.85667107, 2.03590816]),
#  array([3.85522867, 2.02725376]),
#  array([3.85485364, 2.02500361]),
#  array([3.8572565 , 2.02740647]),
#  array([3.85682259, 2.02480303]),
#  array([3.85819796, 2.02892913]),
#  array([3.8575625, 2.0251164]),
#  array([3.85990893, 2.02746282]),
#  array([3.85941521, 2.02450052]),
#  array([3.86075687, 2.02852551]),
#  array([3.86011867, 2.02469632]),
#  array([3.86143452, 2.02864386]),
#  array([3.86076857, 2.02464814]),
#  array([3.86207431, 2.02856536]),
#  array([3.86140498, 2.02454938]),
#  array([3.86270392, 2.0284462 ]),
#  array([3.8620363 , 2.02444046]),
#  array([3.86186271, 2.02339897]),
#  array([3.86415748, 2.02569374]),
#  array([3.86379108, 2.02349535]),
#  array([3.86604535, 2.02574962]),
#  array([3.86820945, 2.02791372]),
#  array([3.86917044, 2.03079668]),
#  array([3.86993923, 2.03310306]),
#  array([3.86856808, 2.02487615]),
#  array([3.86970415, 2.02828436]),
#  array([3.870613  , 2.03101092]),
#  array([3.87258053, 2.03297844]),
#  array([3.87446935, 2.03486727]),
#  array([3.87628261, 2.03668053]),
#  array([3.8743553 , 2.02511664]),
#  array([3.87636586, 2.0271272 ]),
#  array([3.878296  , 2.02905734]),
#  array([3.88014893, 2.03091027]),
#  array([3.88192775, 2.03268909]),
#  array([3.8803665 , 2.02332161]),
#  array([3.88135988, 2.02630173]),
#  array([3.88215457, 2.02868583]),
#  array([3.88279033, 2.03059311]),
#  array([3.88452266, 2.03232544]),
#  array([3.88489268, 2.0334355 ]),
#  array([3.8851887 , 2.03432355]),
#  array([3.88542551, 2.03503399]),
#  array([3.88351293, 2.02355845]),
#  array([3.88301565, 2.02057482]),
#  array([3.88494384, 2.02250301]),
#  array([3.88454461, 2.02010758]),
#  array([3.88645156, 2.02201454]),
#  array([3.88740166, 2.02486483]),
#  array([3.88666985, 2.02047395]),
#  array([3.88852697, 2.02233108]),
#  array([3.8880767 , 2.01962947]),
#  array([3.8891374 , 2.02281156]),
#  array([3.89089842, 2.02457258]),
#  array([3.892589  , 2.02626316]),
#  array([3.89421196, 2.02788612]),
#  array([3.89577   , 2.02944416]),
#  array([3.89726571, 2.03093987]),
#  array([3.89746401, 2.03153475]),
#  array([3.89762264, 2.03201066]),
#  array([3.89582891, 2.02124827]),
#  array([3.89663743, 2.02367384]),
#  array([3.89823121, 2.02526762]),
#  array([3.89723447, 2.01928719]),
#  array([3.89813255, 2.02198143]),
#  array([3.89885101, 2.02413682]),
#  array([3.90039126, 2.02567706]),
#  array([3.90084281, 2.02703171]),
#  array([3.90120405, 2.02811544]),
#  array([3.89980612, 2.01972784]),
#  array([3.90062632, 2.02218846]),
#  array([3.90128249, 2.02415696]),
#  array([3.900358  , 2.01861005]),
#  array([3.90011764, 2.01716785]),
#  array([3.90005514, 2.01679288]),
#  array([3.90104647, 2.01976685]),
#  array([3.9026302 , 2.02135059]),
#  array([3.90415059, 2.02287097]),
#  array([3.90332306, 2.0179058 ]),
#  array([3.9031079 , 2.01661486]),
#  array([3.90471344, 2.0182204 ]),
#  array([3.90625477, 2.01976173]),
#  array([3.90575827, 2.01678271]),
#  array([3.90730745, 2.01833189]),
#  array([3.90696147, 2.01625604]),
#  array([3.90784688, 2.01891226]),
#  array([3.90855521, 2.02103724]),
#  array([3.90912187, 2.02273723]),
#  array([3.91048468, 2.02410004]),
#  array([3.91179299, 2.02540835]),
#  array([3.91304896, 2.02666432]),
#  array([3.91158827, 2.01790013]),
#  array([3.91228249, 2.01998281]),
#  array([3.91363719, 2.02133751]),
#  array([3.91280394, 2.01633804]),
#  array([3.91356758, 2.01862896]),
#  array([3.91306075, 2.015588  ]),
#  array([3.91448778, 2.01701502]),
#  array([3.91415622, 2.01502567]),
#  array([3.91407001, 2.01450844]),
#  array([3.91491811, 2.01705272]),
#  array([3.91559658, 2.01908815]),
#  array([3.91690289, 2.02039445]),
#  array([3.91815694, 2.0216485 ]),
#  array([3.91719598, 2.01588275]),
#  array([3.91694613, 2.01438365]),
#  array([3.91688117, 2.01399389]),
#  array([3.91686428, 2.01389255]),
#  array([3.91685989, 2.0138662 ]),
#  array([3.91769072, 2.01635869]),
#  array([3.91835538, 2.01835268]),
#  array([3.91962122, 2.01961852]),
#  array([3.92083643, 2.02083373]),
#  array([3.92116968, 2.02183347]),
#  array([3.92012627, 2.01557301]),
#  array([3.92141228, 2.01685902]),
#  array([3.92096095, 2.01415105]),
#  array([3.92084361, 2.01344698]),
#  array([3.9208131 , 2.01326392]),
#  array([3.921601  , 2.01562763]),
#  array([3.92285643, 2.01688306]),
#  array([3.92406164, 2.01808827]),
#  array([3.92340981, 2.01417732]),
#  array([3.92409098, 2.01622081]),
#  array([3.92463591, 2.01785561]),
#  array([3.92578608, 2.01900578]),
#  array([3.92689024, 2.02010994]),
#  array([3.92795024, 2.02116994]),
#  array([3.92896783, 2.02218753]),
#  array([3.92994473, 2.02316443]),
#  array([3.92995597, 2.02319815]),
#  array([3.92857307, 2.01490076]),
#  array([3.92970359, 2.01603129]),
#  array([3.92918577, 2.01292433]),
#  array([3.92905113, 2.01211652]),
#  array([3.93022778, 2.01329317]),
#  array([3.93082563, 2.01508673]),
#  array([3.93190739, 2.01616848]),
#  array([3.93229913, 2.01734371]),
#  array([3.93330627, 2.01835086]),
#  array([3.9335391 , 2.01904933]),
#  array([3.93448733, 2.01999756]),
#  array([3.93459773, 2.02032876]),
#  array([3.93468605, 2.02059372]),
#  array([3.9347567 , 2.02080569]),
#  array([3.93356489, 2.01365479]),
#  array([3.93325502, 2.01179555]),
#  array([3.93388218, 2.01367705]),
#  array([3.934931  , 2.01472587]),
#  array([3.93593786, 2.01573273]),
#  array([3.93690445, 2.01669932]),
#  array([3.93616244, 2.01224728]),
#  array([3.93670436, 2.01387302]),
#  array([3.93630551, 2.01147992]),
#  array([3.9362018 , 2.01085772]),
#  array([3.93682631, 2.01273122]),
#  array([3.93732591, 2.01423002]),
#  array([3.93687179, 2.0115053 ]),
#  array([3.93744403, 2.01322204]),
#  array([3.93843071, 2.01420872]),
#  array([3.93880957, 2.0153453 ]),
#  array([3.93972648, 2.01626221]),
#  array([3.93898048, 2.01178624]),
#  array([3.9394937 , 2.01332589]),
#  array([3.93990427, 2.01455761]),
#  array([3.94081503, 2.01546837]),
#  array([3.94014253, 2.01143334]),
#  array([3.94065368, 2.01296679]),
#  array([3.94028459, 2.01075226]),
#  array([3.94083376, 2.01239978]),
#  array([3.94176909, 2.01333511]),
#  array([3.94266701, 2.01423302]),
#  array([3.9421057 , 2.01086521]),
#  array([3.94304629, 2.01180579]),
#  array([3.94394924, 2.01270875]),
#  array([3.94354521, 2.01028454]),
#  array([3.94344016, 2.00965425]),
#  array([3.94437827, 2.01059236]),
#  array([3.94421962, 2.00964047]),
#  array([3.9447568 , 2.01125201]),
#  array([3.94451143, 2.00977975]),
#  array([3.94444763, 2.00939696]),
#  array([3.94499486, 2.01103865]),
#  array([3.94587419, 2.01191798]),
#  array([3.94624163, 2.01302029]),
#  array([3.94705639, 2.01383505]),
#  array([3.94645505, 2.01022705]),
#  array([3.94691233, 2.01159888]),
#  array([3.94658222, 2.00961821]),
#  array([3.94707348, 2.011092  ]),
#  array([3.94680097, 2.00945694]),
#  array([3.94729754, 2.01094663]),
#  array([3.94769479, 2.01213839]),
#  array([3.94849812, 2.01294172]),
#  array([3.94797516, 2.00980391]),
#  array([3.94783918, 2.00898808]),
#  array([3.94834312, 2.01049987]),
#  array([3.94874626, 2.01170931]),
#  array([3.94953715, 2.0125002 ]),
#  array([3.94979639, 2.01327793]),
#  array([3.94920711, 2.00974225]),
#  array([3.94963844, 2.01103622]),
#  array([3.95042494, 2.01182273]),
#  array([3.94999772, 2.00925937]),
#  array([3.94988664, 2.0085929 ]),
#  array([3.95071705, 2.00942331]),
#  array([3.95057191, 2.00855248]),
#  array([3.95104732, 2.00997872]),
#  array([3.9518268, 2.0107582]),
#  array([3.9525751, 2.0115065]),
#  array([3.95283321, 2.01228082]),
#  array([3.9530397 , 2.01290028]),
#  array([3.95243087, 2.00924732]),
#  array([3.95282741, 2.01043695]),
#  array([3.95314465, 2.01138865]),
#  array([3.95271512, 2.00881146]),
#  array([3.95348459, 2.00958093]),
#  array([3.95422328, 2.01031962]),
#  array([3.95451963, 2.01120869]),
#  array([3.95520507, 2.01189413]),
#  array([3.95538732, 2.01244088]),
#  array([3.95603075, 2.01308432]),
#  array([3.95612508, 2.01336729]),
#  array([3.95673523, 2.01397745]),
#  array([3.95676188, 2.01405739]),
#  array([3.95734549, 2.01464101]),
#  array([3.95732012, 2.0145649 ]),
#  array([3.95642593, 2.00919976]),
#  array([3.95674543, 2.01015824]),
#  array([3.95740736, 2.01082017]),
#  array([3.95804281, 2.01145562]),
#  array([3.95819461, 2.01191104]),
#  array([3.9576014 , 2.00835174]),
#  array([3.95828233, 2.00903268]),
#  array([3.95803277, 2.00753527]),
#  array([3.95796788, 2.00714594]),
#  array([3.9586656 , 2.00784367]),
#  array([3.95933542, 2.00851348]),
#  array([3.95997844, 2.0091565 ]),
#  array([3.95968009, 2.00736641]),
#  array([3.95960252, 2.00690098]),
#  array([3.95999641, 2.00808266]),
#  array([3.96031152, 2.00902799]),
#  array([3.96002193, 2.00729046]),
#  array([3.95994664, 2.0068387 ]),
#  array([3.96033738, 2.00801093]),
#  array([3.96097042, 2.00864397]),
#  array([3.96071373, 2.00710386]),
#  array([3.96135738, 2.00774751]),
#  array([3.96166538, 2.00867151]),
#  array([3.96191178, 2.00941072]),
#  array([3.96154426, 2.00720559]),
#  array([3.96188104, 2.00821593]),
#  array([3.96215047, 2.0090242 ]),
#  array([3.96272697, 2.0096007 ]),
#  array([3.96232035, 2.00716096]),
#  array([3.96221463, 2.00652663]),
#  array([3.9628398, 2.0071518]),
#  array([3.96343997, 2.00775197]),
#  array([3.96370605, 2.00855022]),
#  array([3.9634059 , 2.00674933]),
#  array([3.96332787, 2.00628111]),
#  array([3.96330758, 2.00615937]),
#  array([3.96391824, 2.00677003]),
#  array([3.96423367, 2.00771633]),
#  array([3.96402304, 2.00645253]),
#  array([3.96435543, 2.00744969]),
#  array([3.96491932, 2.00801359]),
#  array([3.96546067, 2.00855493]),
#  array([3.96512486, 2.0065401 ]),
#  array([3.96503755, 2.00601625]),
#  array([3.96561647, 2.00659517]),
#  array([3.96617224, 2.00715094]),
#  array([3.96599068, 2.00606159]),
#  array([3.96594348, 2.00577836]),
#  array([3.96627791, 2.00678165]),
#  array([3.96613855, 2.00594551]),
#  array([3.96610232, 2.00572812]),
#  array([3.9660929 , 2.00567159]),
#  array([3.96643075, 2.00668513]),
#  array([3.96629991, 2.00590015]),
#  array([3.9662659 , 2.00569605]),
#  array([3.96625705, 2.00564299]),
#  array([3.96659333, 2.00665183]),
#  array([3.96686236, 2.0074589 ]),
#  array([3.96663004, 2.00606501]),
#  array([3.96693354, 2.0069755 ]),
#  array([3.96745536, 2.00749732]),
#  array([3.96765641, 2.00810048]),
#  array([3.96814128, 2.00858535]),
#  array([3.96774821, 2.00622694]),
#  array([3.96826871, 2.00674744]),
#  array([3.96809364, 2.00569704]),
#  array([3.96804812, 2.00542393]),
#  array([3.96803629, 2.00535293]),
#  array([3.9685685 , 2.00588514]),
#  array([3.96884402, 2.00671171]),
#  array([3.96866174, 2.00561799]),
#  array([3.96917614, 2.0061324 ]),
#  array([3.96905673, 2.00541593]),
#  array([3.96956728, 2.00592648]),
#  array([3.96982035, 2.00668568]),
#  array([3.96962166, 2.00549355]),
#  array([3.96957   , 2.00518359]),
#  array([3.96955657, 2.00510301]),
#  array([3.96985926, 2.00601107]),
#  array([3.97010141, 2.00673752]),
#  array([3.96989087, 2.00547434]),
#  array([3.9701646, 2.0062955]),
#  array([3.97000584, 2.00534299]),
#  array([3.97049887, 2.00583601]),
#  array([3.97038857, 2.00517422]),
#  array([3.97087731, 2.00566296]),
#  array([3.97078021, 2.00508035]),
#  array([3.97075496, 2.00492887]),
#  array([3.97124129, 2.0054152 ]),
#  array([3.97170816, 2.00588207]),
#  array([3.97156815, 2.005042  ]),
#  array([3.97203594, 2.0055098 ]),
#  array([3.97193405, 2.00489843]),
#  array([3.97190756, 2.00473947]),
#  array([3.97237462, 2.00520653]),
#  array([3.97230234, 2.00477288]),
#  array([3.97228355, 2.00466012]),
#  array([3.97255827, 2.00548429]),
#  array([3.97299742, 2.00592344]),
#  array([3.97318206, 2.00647737]),
#  array([3.97294114, 2.00503182]),
#  array([3.97318041, 2.00574962]),
#  array([3.97360181, 2.00617102]),
#  array([3.97400635, 2.00657556]),
#  array([3.97439471, 2.00696393]),
#  array([3.97407115, 2.00502253]),
#  array([3.97398702, 2.00451777]),
#  array([3.97441692, 2.00494768]),
#  array([3.97482963, 2.00536038]),
#  array([3.97522583, 2.00575658]),
#  array([3.97503052, 2.00458474]),
#  array([3.97497974, 2.00428007]),
#  array([3.97496654, 2.00420085]),
#  array([3.97496311, 2.00418025]),
#  array([3.97496222, 2.0041749 ]),
#  array([3.97521248, 2.00492568]),
#  array([3.97541269, 2.00552631]),
#  array([3.97579391, 2.00590753]),
#  array([3.97556913, 2.00455884]),
#  array([3.97596657, 2.00495628]),
#  array([3.97634811, 2.00533782]),
#  array([3.97618061, 2.00433282]),
#  array([3.97639703, 2.00498207]),
#  array([3.97676944, 2.00535449]),
#  array([3.97659152, 2.00428692]),
#  array([3.97697395, 2.00466936]),
#  array([3.97687415, 2.00407055]),
#  array([3.97709243, 2.0047254 ]),
#  array([3.97745607, 2.00508904]),
#  array([3.97760161, 2.00552565]),
#  array([3.97793907, 2.0058631 ])]

# %%
def init():
    ax.set_xlim(0, 10)
    ax.set_ylim(0, 10)
    return ln,
